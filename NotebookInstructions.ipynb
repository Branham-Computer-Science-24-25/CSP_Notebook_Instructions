# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Branham-Computer-Science-24-25/CSP_Notebook_Instructions/blob/main/NotebookInstructions.ipynb)

# %% [markdown]
# # How to Take Notes

# %% [markdown]
# **Bold Step Numbers and Titles**
#
# This is an example of a text cell. Use a blank line to start a new paragraph.
#
# Record important information that can be useful in the future such as definitions, takeaways/conclusions, and code snippets that worked.

# %%
print("This is an example of a code cell",
      "Clicking the run button (triangle) to the left will run the cell.")
# Out:
# This is an example of a code cell Clicking the run button (triangle) to the left will run the cell.

# %% [markdown]
# The output will be shown below the code cell and will stay there unless deleted.

# %%
print("Errors in the code will be shown along with the error message" such as this)
# Out:
#   File "<ipython-input-2-75c56a344562>", line 1
#     print("Errors in the code will be shown along with the error message" such as this)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# You can fix the mistake and rerun the cell.
#
# Or you can leave it as an example of what happens when a mistake is made. If you do this, you should expalin in a text cell below what caused the error and how you fixed it.

# %% [markdown]
# **Tips**
# *   Keep a separate section as a glossary to keep all the vocabulary terms and definitions. Being able to find terms quicker will make your notebook more useful.
# *   Keyboard shortcuts can be found under the Tools menu.
#    *   When you are done editing a cell click ESC to unfocus (exit) it.
#    *   Save your work often by clicking Ctrl + S.
#    *   Run the focused (current) cell with Ctrl + Enter.
# *   You can change to a dark theme under settings.
# *   Quickly add cells by hovering over the line above or below an existing cell and clicking "+ Code" or "+ Text".

# %% [markdown]
# **Remember**
#
#
# *   You can edit this notebook and should be seen as a living, growing document.
# *   This notebook is for you to use in future lessons and projects as well as a study tool.
# *   This notebook is for you. Follow the format that works best for *you*. If your notebook isn't helpful, reach out for support.

# %% [markdown]
# # Debugging

# %% [markdown]
# Learn how to debug using Google Collab.
# [Article](https://colab.research.google.com/drive/1LlOO48_UsUmSfCW1CPCtltPLf2zx8aVK#scrollTo=z0EPwQ60SXOM&line=2&uniqifier=1)

# %%
# !pip install -Uqq ipdb
import ipdb

# %%
# %pdb on
# Out:
# Automatic pdb calling has been turned ON

# %%
def print_sample(start, max, increment):
  ipdb.set_trace(context=6)
  for i in range(start, max, increment):
    print(i)

# %%
print_sample(0, 5, 2)
# Out:
# > <ipython-input-12-0be1269f830b>(3)print_sample()
#       1 def print_sample(start, max, increment):
#       2   ipdb.set_trace(context=6)
# ----> 3   for i in range(start, max, increment):
#       4     print(i)
#
# ipdb> n
# > <ipython-input-12-0be1269f830b>(4)print_sample()
#       1 def print_sample(start, max, increment):
#       2   ipdb.set_trace(context=6)
#       3   for i in range(start, max, increment):
# ----> 4     print(i)
#
# ipdb> n
# 0
# > <ipython-input-12-0be1269f830b>(3)print_sample()
#       1 def print_sample(start, max, increment):
#       2   ipdb.set_trace(context=6)
# ----> 3   for i in range(start, max, increment):
#       4     print(i)
#
# ipdb> i
# 0
# ipdb> n
# > <ipython-input-12-0be1269f830b>(4)print_sample()
#       1 def print_sample(start, max, increment):
#       2   ipdb.set_trace(context=6)
#       3   for i in range(start, max, increment):
# ----> 4     print(i)
#
# ipdb> i
# 2
# ipdb> n
# 2
# ...

# %% [markdown]
# # How to Upload Images

# %% [markdown]
# **Adding to a Text Cell**
#
# Below are two options for uploading an image to a text cell. Note that iPhone images using .HEIC will need to be converted to another image type (such as jpg) before being used in Google Collab. You can use this [website](https://heictojpg.com/), but any online converter should work.
# 1.   Upload an image from the computer by clicking on the Insert image button. Taking a screenshot, saving it to the computer, and inserting the image this way is a quick method to display graphical output such as from the Turtle module.
# ![InsertImage.png](data:image/png;base64,...)
# 2.   Include an image from your Google Drive following these steps. [Article](https://towardsdatascience.com/the-2-step-guide-to-upload-images-in-google-colab-b51348e882e4) /  [Video](https://youtu.be/vlheEeZd6lY?si=AQUC2EokSakupLBH)

# %% [markdown]
# **Adding to a Code Cell**
#
# Follow the steps below to add an image from your computer to your code cell. [Video](https://youtu.be/TW_0VPCMM70?si=Tykwa7g6Z2BHqcSw)

# %%
from google.colab import files
from IPython import display

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6aaf922c-b7d6-4892-8dbc-4f8e3f691734" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6aaf922c-b7d6-4892-8dbc-4f8e3f691734">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
display.Image("bruin logo.jpg")

# %% [markdown]
# # How to Embed trinket (Turtle Code) in Colab

# %% [markdown]
# ## Steps
# 1.   Click the Trinket.io button and open "View on trinket.io"
# ![trinketio_step1.png](data:image/png;base64,...)
# 2.   Click "Log In"
# ![trinketio_step2.png](data:image/png;base64,...)
# 3.   Click "Sing in with Google" and select your school gmail account
# ![trinketio_step3.png](data:image/png;base64,...)
# 4.   After you have logged in, click "go back" on your browser until you have returned to your code
# ![trinketio_step4.png](data:image/png;base64,...)
# 5.   Click the "Share" menu and click "Link"
# ![trinketio_step5.png](data:image/png;base64,...)
# 6.   Copy the link to your code
# ![trinketio_step6.png](data:image/png;base64,...)
# 7.   Copy the code below into a cell in your notebook and replace YOUR_LINK_HERE with your copied link from step 6
#
# 8.   Add "embed/" between ".io/" and "pygame"

# %%
from IPython.display import IFrame
IFrame(src='YOUR_LINK_HERE', width="100%", height="356")

# %% [markdown]
# ##Sample trinket code running in Google Colab
# Run the cell to see how you run and edit the code.

# %%
from IPython.display import IFrame
IFrame(src='https://trinket.io/embed/pygame/e13cc02918', width="100%", height="356")
# Out:
#         <iframe
#             width="100%"
#             height="356"
#             src="https://trinket.io/embed/pygame/e13cc02918"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
